# %%
p = 21888242871839275222246405745257275088548364400416034343698204186575808495617

# %%
from tensorflow.keras.layers import Input, BatchNormalization, Dense, Flatten
from tensorflow.keras import Model
import numpy as np

# %%
inputs = Input(shape=(5,5,3))
out = BatchNormalization()(inputs)
out = Flatten()(out)
out = Dense(1)(out)
model = Model(inputs, out)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 5, 5, 3)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 5, 5, 3)        │            12 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 75)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            76 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 88 (352.00 B)
#  Trainable params: 82 (328.00 B)
#  Non-trainable params: 6 (24.00 B)

# %%
X_train = np.random.rand(100,5,5,3)
X_train
# Out:
# array([[[[0.60384591, 0.76706998, 0.80850231],
#          [0.45634106, 0.18998775, 0.34212406],
#          [0.9673473 , 0.35235242, 0.16139093],
#          [0.4514518 , 0.33113734, 0.03990953],
#          [0.75386766, 0.70881806, 0.24837283]],
#
#         [[0.20110148, 0.36590138, 0.81593574],
#          [0.48455094, 0.92046105, 0.00140346],
#          [0.45389422, 0.88912959, 0.74518631],
#          [0.38341597, 0.76196896, 0.43028356],
#          [0.06075796, 0.09361846, 0.85107977]],
#
#         [[0.55710624, 0.16777536, 0.11976239],
#          [0.78132667, 0.92576022, 0.98343163],
#          [0.7774776 , 0.97083323, 0.97957192],
#          [0.45701702, 0.59291996, 0.24702148],
#          [0.91797784, 0.33409993, 0.46745264]],
#
#         [[0.85169133, 0.38708603, 0.34616611],
#          [0.17657783, 0.11355016, 0.12754369],
#          [0.78479318, 0.70544173, 0.56921611],
#          [0.53588168, 0.63313098, 0.28312233],
#          [0.83639061, 0.05613458, 0.03641011]],
#
#         [[0.71609491, 0.05271848, 0.73299899],
#          [0.74994368, 0.40829534, 0.26602831],
#          [0.2332587 , 0.52094307, 0.53563896],
#          [0.26419981, 0.24379621, 0.68445498],
#          [0.52713824, 0.65007971, 0.10908579]]],
#
#
#        [[[0.15676735, 0.3616246 , 0.70549584],
#          [0.45915994, 0.26577704, 0.04750646],
#          [0.85444643, 0.94944828, 0.24046429],
#          [0.36074408, 0.41694019, 0.79732406],
#          [0.97083617, 0.55778901, 0.49589488]],
#
#         [[0.49785373, 0.35690391, 0.49146027],
#          [0.9653999 , 0.68170272, 0.33688265],
#          [0.5194879 , 0.87466864, 0.77756615],
#          [0.23681611, 0.75671511, 0.48185682],
#          [0.4634669 , 0.02492621, 0.21515699]],
#
#         [[0.63707472, 0.87893016, 0.23068574],
#          [0.33169246, 0.11202505, 0.20148364],
#          [0.54836944, 0.86279992, 0.8365622 ],
#          [0.45913264, 0.18379759, 0.30875829],
#          [0.83568308, 0.16297966, 0.54821122]],
#
#         [[0.61944493, 0.49960643, 0.46956107],
#          [0.7352076 , 0.05818973, 0.64247723],
#          [0.25606394, 0.30625097, 0.58863588],
#          [0.84170561, 0.610291  , 0.14954311],
#          [0.70052809, 0.78248198, 0.73976048]],
#
#         [[0.65249208, 0.99726497, 0.02524274],
#          [0.99771681, 0.55483928, 0.96064029],
#          [0.72483144, 0.98726138, 0.22410476],
#          [0.69358776, 0.32768338, 0.26169945],
#          [0.07726333, 0.6969326 , 0.54028917]]],
#
#
#        [[[0.40367335, 0.86099883, 0.78471889],
#          [0.3584737 , 0.78373145, 0.09472859],
#          [0.07642968, 0.70134086, 0.42235501],
#          [0.4559232 , 0.51789775, 0.76878776],
#          [0.90660941, 0.1779942 , 0.70988832]],
#
#         [[0.9427705 , 0.65251244, 0.70469299],
#          [0.40351946, 0.89407483, 0.27580601],
#          [0.4254422 , 0.3768483 , 0.86614088],
#          [0.79095024, 0.22995277, 0.38362648],
#          [0.70496646, 0.2076944 , 0.41177213]],
#
#         [[0.60945547, 0.25673827, 0.28004248],
#          [0.58599563, 0.66106003, 0.51356712],
#          [0.45925743, 0.03410418, 0.89976815],
#          [0.64372985, 0.10395559, 0.02093916],
#          [0.26100489, 0.32051235, 0.86599741]],
#
#         [[0.36944532, 0.61351768, 0.96957665],
#          [0.49596308, 0.63906509, 0.36368982],
#          [0.62523871, 0.34003701, 0.17954878],
#          [0.02982437, 0.28572351, 0.15837064],
#          [0.96639462, 0.3521908 , 0.89009809]],
#
#         [[0.66756679, 0.18515374, 0.4330157 ],
#          [0.15636552, 0.85713573, 0.48175505],
#          [0.67011224, 0.290596  , 0.64196273],
#          [0.0819355 , 0.68446085, 0.31478488],
#          [0.22732145, 0.41848364, 0.40288094]]],
#
#
#        ...,
#
#
#        [[[0.77871213, 0.96535161, 0.0038453 ],
#          [0.67792749, 0.93397572, 0.18661572],
#          [0.19985212, 0.24599101, 0.99327604],
#          [0.0331211 , 0.33634412, 0.12297446],
#          [0.1639396 , 0.13966629, 0.54691567]],
#
#         [[0.20639602, 0.08975993, 0.47048377],
#          [0.55466204, 0.6847547 , 0.13869704],
#          [0.4086492 , 0.81438535, 0.68459525],
#          [0.31693889, 0.98184572, 0.75789271],
#          [0.59893688, 0.96799229, 0.94284687]],
#
#         [[0.42005786, 0.09090567, 0.01557741],
#          [0.54533054, 0.58560203, 0.92151547],
#          [0.11729032, 0.7872312 , 0.37306898],
#          [0.23408242, 0.81927533, 0.17596718],
#          [0.58773947, 0.72934953, 0.67651696]],
#
#         [[0.7329942 , 0.6842027 , 0.46446035],
#          [0.40557808, 0.84625577, 0.32841205],
#          [0.47938564, 0.50834449, 0.98827706],
#          [0.25797336, 0.17410889, 0.02660796],
#          [0.61702374, 0.93742802, 0.58381145]],
#
#         [[0.21090999, 0.10567982, 0.19045637],
#          [0.51731858, 0.24622114, 0.39780983],
#          [0.30923217, 0.57528797, 0.64585613],
#          [0.26060664, 0.72886864, 0.19082173],
#          [0.0407166 , 0.48940402, 0.68409978]]],
#
#
#        [[[0.0070152 , 0.09058928, 0.85795613],
#          [0.55777705, 0.01906417, 0.90677288],
#          [0.61872434, 0.30633782, 0.23743283],
#          [0.02190758, 0.78081119, 0.40259046],
#          [0.27031599, 0.61200024, 0.65565218]],
#
#         [[0.63682981, 0.97827054, 0.07210037],
#          [0.91011184, 0.15037703, 0.91435335],
#          [0.22807463, 0.68590159, 0.69793979],
#          [0.75146925, 0.49407832, 0.20108149],
#          [0.72625735, 0.65096901, 0.13286729]],
#
#         [[0.65248651, 0.27796674, 0.69562002],
#          [0.88051348, 0.15817063, 0.42004737],
#          [0.60025142, 0.72161902, 0.85476218],
#          [0.04333736, 0.85598902, 0.50425054],
#          [0.24690271, 0.13152855, 0.3156483 ]],
#
#         [[0.96522048, 0.64065529, 0.1267704 ],
#          [0.55789324, 0.38193645, 0.2806196 ],
#          [0.35651794, 0.26051   , 0.27113653],
#          [0.31640787, 0.31877119, 0.78360021],
#          [0.19824647, 0.46456933, 0.06785879]],
#
#         [[0.84816129, 0.6608291 , 0.03491026],
#          [0.59184114, 0.44792647, 0.32198922],
#          [0.67902485, 0.75235934, 0.66919499],
#          [0.82629435, 0.89682813, 0.17492793],
#          [0.70511185, 0.8915699 , 0.01283675]]],
#
#
#        [[[0.71622527, 0.22272732, 0.36332765],
#          [0.57116729, 0.75537907, 0.66776253],
#          [0.6240227 , 0.33572688, 0.78282037],
#          [0.46650728, 0.20548761, 0.86369642],
#          [0.086824  , 0.52837118, 0.79934678]],
#
#         [[0.81985207, 0.79666438, 0.02748458],
#          [0.6912473 , 0.11765773, 0.97447566],
#          [0.79547074, 0.65616075, 0.29851031],
#          [0.67693202, 0.72598565, 0.72362782],
#          [0.84163379, 0.56792079, 0.56528014]],
#
#         [[0.0699092 , 0.87212387, 0.78401149],
#          [0.27956874, 0.81084969, 0.20363382],
#          [0.27318267, 0.29537377, 0.66231579],
#          [0.73744714, 0.31909558, 0.89997393],
#          [0.29545994, 0.70085049, 0.7517868 ]],
#
#         [[0.57104819, 0.60434582, 0.60428518],
#          [0.51943354, 0.0644373 , 0.42907793],
#          [0.72816606, 0.53117344, 0.95979735],
#          [0.16078415, 0.39727608, 0.67565009],
#          [0.50702556, 0.49023221, 0.7392996 ]],
#
#         [[0.36367512, 0.79526809, 0.96784975],
#          [0.96578998, 0.58484276, 0.94615154],
#          [0.39062444, 0.35483334, 0.48999181],
#          [0.56123267, 0.42182942, 0.1290881 ],
#          [0.85700019, 0.95981161, 0.6156564 ]]]])

# %%
y_train = np.random.rand(100,1)
y_train
# Out:
# array([[8.19095985e-01],
#        [4.59638382e-01],
#        [7.54672658e-01],
#        [1.51200390e-01],
#        [4.78800256e-01],
#        [8.41520844e-01],
#        [2.48384407e-01],
#        [2.68887463e-01],
#        [5.94268325e-02],
#        [1.47597931e-04],
#        [3.10540143e-01],
#        [2.37477328e-01],
#        [4.64621534e-03],
#        [8.65580081e-02],
#        [9.68020129e-01],
#        [3.07443048e-01],
#        [1.83834250e-01],
#        [5.05352261e-01],
#        [6.98174841e-01],
#        [6.43714232e-01],
#        [6.39176137e-01],
#        [8.78077983e-01],
#        [2.37425062e-02],
#        [9.27386748e-02],
#        [6.32237403e-01],
#        [7.30487914e-01],
#        [4.79035662e-01],
#        [5.17103050e-01],
#        [3.06989897e-01],
#        [7.45704705e-01],
#        [4.30433284e-01],
#        [8.02704068e-01],
#        [8.90053066e-01],
#        [5.34460824e-01],
#        [6.72815231e-01],
#        [2.68878619e-01],
#        [9.30288083e-01],
#        [4.42969318e-01],
#        [3.27714444e-01],
#        [4.84329571e-01],
#        [7.20376001e-01],
#        [5.82291502e-01],
#        [8.17397266e-01],
#        [3.11419616e-01],
#        [6.30050475e-01],
#        [9.36545214e-01],
#        [3.70875170e-01],
#        [2.36548828e-01],
#        [3.37970185e-01],
#        [7.63906946e-01],
#        [4.38326133e-02],
#        [9.67949949e-01],
#        [9.01578175e-02],
#        [1.88978484e-01],
#        [4.33319838e-01],
#        [1.23990542e-01],
#        [1.54472714e-01],
#        [5.97066054e-01],
#        [5.50426378e-01],
#        [6.61034455e-01],
#        [4.45791433e-01],
#        [3.50018893e-01],
#        [7.98015569e-01],
#        [4.22335735e-02],
#        [5.77812704e-01],
#        [4.34939584e-02],
#        [4.14609608e-01],
#        [7.71457570e-01],
#        [6.19527157e-01],
#        [3.36230826e-01],
#        [2.08929271e-01],
#        [9.73352599e-02],
#        [7.63301178e-01],
#        [9.45817879e-01],
#        [2.87646231e-02],
#        [8.58509331e-01],
#        [7.28413955e-01],
#        [3.27197608e-02],
#        [5.99611060e-01],
#        [8.70456154e-01],
#        [8.71937665e-01],
#        [1.76774914e-01],
#        [8.88108085e-01],
#        [6.15112864e-01],
#        [6.94146911e-01],
#        [7.06975855e-01],
#        [1.68632867e-01],
#        [4.00793804e-01],
#        [4.66495333e-01],
#        [9.86110684e-01],
#        [8.93594556e-03],
#        [3.16047745e-01],
#        [1.43595637e-01],
#        [4.87179765e-01],
#        [8.64406583e-02],
#        [9.38271265e-01],
#        [9.00822579e-01],
#        [5.13407404e-01],
#        [1.98883197e-01],
#        [2.06232597e-01]])

# %%
model.compile("adam", "mse")
model.fit(X_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7256
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step - loss: 1.9723
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - loss: 1.7441
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - loss: 1.8540
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - loss: 1.7174
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step - loss: 1.5487
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - loss: 1.6692
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - loss: 1.5148
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - loss: 1.3181
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - loss: 1.4388

# %%
model.layers[1].weights
# Out:
# [<KerasVariable shape=(3,), dtype=float32, path=batch_normalization/gamma>,
#  <KerasVariable shape=(3,), dtype=float32, path=batch_normalization/beta>,
#  <KerasVariable shape=(3,), dtype=float32, path=batch_normalization/moving_mean>,
#  <KerasVariable shape=(3,), dtype=float32, path=batch_normalization/moving_variance>]

# %%
X = np.random.rand(1,5,5,3)
X
# Out:
# array([[[[0.42583122, 0.66518831, 0.45544763],
#          [0.98964015, 0.64755069, 0.46357053],
#          [0.26988113, 0.1488036 , 0.01966642],
#          [0.22859392, 0.0172811 , 0.0622273 ],
#          [0.24630139, 0.79205505, 0.96098949]],
#
#         [[0.1869114 , 0.60629408, 0.43855849],
#          [0.55321532, 0.24176446, 0.23207878],
#          [0.44428208, 0.33443009, 0.67289542],
#          [0.31305482, 0.38332418, 0.30089677],
#          [0.4795198 , 0.82724105, 0.17635053]],
#
#         [[0.90115444, 0.54430382, 0.83045872],
#          [0.77412927, 0.75494886, 0.62754472],
#          [0.04287335, 0.63631401, 0.82108627],
#          [0.28490576, 0.53365788, 0.98229127],
#          [0.43788597, 0.04012721, 0.87247348]],
#
#         [[0.8473817 , 0.00342018, 0.42719685],
#          [0.63196841, 0.88994495, 0.66634868],
#          [0.8383848 , 0.65584435, 0.85112477],
#          [0.52520182, 0.58175594, 0.82414076],
#          [0.3701879 , 0.85287308, 0.71185781]],
#
#         [[0.17488253, 0.57199013, 0.20313468],
#          [0.46714173, 0.74947683, 0.99837692],
#          [0.35644713, 0.40617694, 0.22931973],
#          [0.43278273, 0.56451906, 0.08163614],
#          [0.2622765 , 0.66736096, 0.36143092]]]])

# %%
new_model = Model(inputs, model.layers[1].output)
y = new_model.predict(X)
y
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# array([[[[ 0.32352948,  0.6077688 ,  0.36199367],
#          [ 0.9775543 ,  0.5872687 ,  0.37135965],
#          [ 0.1426256 ,  0.00757879, -0.14047357],
#          [ 0.09473196, -0.1452888 , -0.09139975],
#          [ 0.11527282,  0.755225  ,  0.9448968 ]],
#
#         [[ 0.04637976,  0.5393165 ,  0.34252006],
#          [ 0.4712965 ,  0.11562647,  0.10444349],
#          [ 0.34493268,  0.22333105,  0.61271673],
#          [ 0.19270757,  0.28016025,  0.18379244],
#          [ 0.38580883,  0.7961214 ,  0.04018736]],
#
#         [[ 0.8749099 ,  0.46726567,  0.7943914 ],
#          [ 0.7275592 ,  0.71209675,  0.5604262 ],
#          [-0.12070602,  0.5742084 ,  0.7835847 ],
#          [ 0.16005433,  0.45489198,  0.96945834],
#          [ 0.33751315, -0.11873493,  0.84283555]],
#
#         [[ 0.81253284, -0.16139922,  0.32941982],
#          [ 0.5626509 ,  0.8690017 ,  0.6051682 ],
#          [ 0.80209637,  0.59690833,  0.8182199 ],
#          [ 0.43880045,  0.51079595,  0.78710663],
#          [ 0.2589826 ,  0.8259133 ,  0.6576414 ]],
#
#         [[ 0.03242613,  0.49944526,  0.07107019],
#          [ 0.37145013,  0.7057367 ,  0.9880055 ],
#          [ 0.24304312,  0.30672187,  0.10126224],
#          [ 0.33159333,  0.49076164, -0.06902084],
#          [ 0.13380414,  0.610294  ,  0.25358993]]]], dtype=float32)

# %%
gamma = model.layers[1].weights[0].numpy()
beta = model.layers[1].weights[1].numpy()
moving_mean = model.layers[1].weights[2].numpy()
moving_var = model.layers[1].weights[3].numpy()
epsilon = model.layers[1].epsilon

# %%
a = gamma/(moving_var+epsilon)**.5
b = beta-gamma*moving_mean/(moving_var+epsilon)**.5

# %%
y-(gamma*(X-moving_mean)/((moving_var+epsilon)**.5)+beta)
# Out:
# array([[[[ 5.80517240e-09,  7.25930150e-08, -2.98457537e-08],
#          [ 8.56541345e-08,  7.81473317e-08,  1.71317017e-08],
#          [ 5.89111010e-09, -4.92505054e-09,  2.11156338e-08],
#          [-1.79105347e-09, -1.58378599e-08,  1.43221258e-08],
#          [-1.09813150e-08,  9.23258275e-08, -6.69148024e-08]],
#
#         [[-1.44543390e-09,  8.13925268e-08, -1.61573844e-08],
#          [ 1.60176437e-08, -7.97089778e-09, -7.92654534e-09],
#          [-7.88321070e-09,  3.77275967e-08, -4.68007141e-08],
#          [ 3.35038775e-09,  1.52393753e-08, -1.96319461e-08],
#          [-9.91450733e-09,  9.66804833e-08,  1.48735822e-08]],
#
#         [[ 6.33648625e-08,  6.39907535e-08, -5.05588529e-08],
#          [ 4.40467959e-08,  6.95079078e-08, -4.06570019e-08],
#          [-1.54599301e-08,  5.38772120e-08, -4.13081969e-08],
#          [-6.06994216e-09,  7.09057760e-08, -5.97652687e-08],
#          [ 3.13480205e-08, -1.03577788e-08, -2.45032028e-08]],
#
#         [[ 2.00998832e-08, -5.13689175e-09,  1.56499594e-08],
#          [-3.29025746e-08,  1.04765461e-07,  1.25684660e-08],
#          [ 5.70490549e-08,  4.29293409e-08, -4.37610360e-08],
#          [-4.86436637e-08,  4.66562766e-08, -3.09323978e-08],
#          [ 8.98801211e-09,  7.49079219e-08, -3.52156148e-08]],
#
#         [[-3.48126632e-09,  8.07223340e-08,  1.09966776e-08],
#          [-4.85870610e-09,  1.16134336e-07, -5.89688829e-08],
#          [-1.32754424e-08,  5.42302385e-08,  8.45523354e-09],
#          [ 3.72076268e-08,  2.18122382e-08,  1.71613281e-08],
#          [ 1.78793408e-09,  3.48072273e-08, -1.69633181e-08]]]])

# %%
y-(a*X+b)
# Out:
# array([[[[-1.05967100e-08,  9.48168908e-08, -5.72857582e-08],
#          [ 4.38327714e-08,  9.96888471e-08, -1.07153514e-08],
#          [-3.47971940e-09, -2.67895506e-09,  1.55131372e-08],
#          [-9.30043764e-09, -1.86800786e-08,  6.58685331e-09],
#          [-1.92890455e-08,  1.19457896e-07, -1.19688103e-07]],
#
#         [[-7.07555017e-09,  1.01337915e-07, -4.27510544e-08],
#          [-6.12738571e-09, -2.12835249e-09, -2.41732750e-08],
#          [-2.51169552e-08,  4.71551698e-08, -8.51372832e-08],
#          [-7.96693944e-09,  2.65585525e-08, -3.93272258e-08],
#          [-2.87369540e-08,  1.25173820e-07,  1.41946074e-09]],
#
#         [[ 2.55329018e-08,  8.15378761e-08, -9.67911038e-08],
#          [ 1.19418003e-08,  9.52044201e-08, -7.67209940e-08],
#          [-1.45960515e-08,  7.49840049e-08, -8.70707831e-08],
#          [-1.61181611e-08,  8.80410308e-08, -1.13606027e-07],
#          [ 1.44026465e-08, -1.23161318e-08, -7.28408625e-08]],
#
#         [[-1.53077185e-08, -8.51535847e-09, -1.03743656e-08],
#          [-5.85982086e-08,  1.35684673e-07, -2.54400381e-08],
#          [ 2.20470810e-08,  6.47917194e-08, -9.10288869e-08],
#          [-6.95256970e-08,  6.56523387e-08, -7.68480481e-08],
#          [-4.90517582e-09,  1.04392905e-07, -7.55046348e-08]],
#
#         [[-8.56905774e-09,  9.93405784e-08, -3.79962925e-09],
#          [-2.31230840e-08,  1.41619148e-07, -1.13615712e-07],
#          [-2.65491238e-08,  6.64335382e-08, -7.65323654e-09],
#          [ 2.04923341e-08,  4.01414436e-08,  8.45345598e-09],
#          [-7.24003874e-09,  5.71151579e-08, -3.96920352e-08]]]])

# %%
X_in = [[[int(X[0][i][j][k]*2**10) for k in range(3)] for j in range(5)] for i in range(5)]
a_in = [int(a[i]*2**10) for i in range(3)]
b_in = [int(b[i]*2**20) for i in range(3)]

# %%
def BatchNormalizationInt(nRows, nCols, nChannels, n, X_in, a_in, b_in):
    X = [[[str(X_in[i][j][k]) for k in range(nChannels)] for j in range(nCols)] for i in range(nRows)]
    A = [str(a_in[k]) for k in range(nChannels)]
    B = [str(b_in[k]) for k in range(nChannels)]
    out = [[[None for _ in range(nChannels)] for _ in range(nCols)] for _ in range(nRows)]
    for i in range(nRows):
        for j in range(nCols):
            for k in range(nChannels):
                out[i][j][k] = (X_in[i][j][k]*a_in[k] + b_in[k])
                out[i][j][k] = str(out[i][j][k] // n)
    return X, A, B, out

# %%
X_in, a_in, b_in, out = BatchNormalizationInt(5, 5, 3, 2**10, X_in, a_in, b_in)
out
# Out:
# [[['330', '622', '369'],
#   ['999', '601', '379'],
#   ['145', '7', '-145'],
#   ['96', '-150', '-95'],
#   ['117', '773', '966']],
#  [['46', '551', '350'],
#   ['481', '117', '106'],
#   ['351', '228', '626'],
#   ['196', '286', '187'],
#   ['394', '814', '40']],
#  [['894', '477', '812'],
#   ['743', '728', '572'],
#   ['-125', '587', '800'],
#   ['162', '465', '991'],
#   ['344', '-122', '861']],
#  [['830', '-166', '336'],
#   ['575', '889', '618'],
#   ['820', '610', '836'],
#   ['447', '522', '804'],
#   ['264', '845', '671']],
#  [['32', '510', '72'],
#   ['379', '721', '1010'],
#   ['248', '312', '102'],
#   ['338', '502', '-72'],
#   ['136', '624', '259']]]

# %%
in_json = {
    "in": X_in,
    "a": a_in,
    "b": b_in,
    "out": out
}

# %%
import json

# %%
with open("batchNormalization_input.json", "w") as f:
    json.dump(in_json, f)
